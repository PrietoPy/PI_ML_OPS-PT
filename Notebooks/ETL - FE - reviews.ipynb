# %%
import pandas as pd # Para trabajar con dataframes
import numpy as np # Para operaciones y funciones con arrays
import gzip # Para cargar archivo gz
import ast  # Para cargar contenido tipo diccionario dentro de los json
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer # modelo entrenado para NPL

# %%
def parseo (ruta):
  # Lista para almacenar los diccionarios JSON
  fjson = []
  # Abre el archivo comprimido en modo lectura binaria ("rb")
  with gzip.open(ruta, "rb") as archivo:
      # Descomprime el contenido del archivo y lo decodifica como utf-8
      contenido = archivo.read().decode("utf-8").splitlines()

      # Recorre cada línea descomprimida
      for fila in contenido:
          # Lee cada línea del archivo como una cadena JSON
          fila_json = ast.literal_eval(fila.strip())

          # Agrega el diccionario JSON a la lista
          fjson.append(fila_json)

  # Crea el DataFrame directamente desde la lista de diccionarios
  df = pd.DataFrame(fjson)
  return df

# %%
reviews = parseo('../Datasets/user_reviews.json.gz')

# %%
reviews.head()
# Out:
#              user_id                                           user_url  \
# 0  76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1            js41637               http://steamcommunity.com/id/js41637
# 2          evcentric             http://steamcommunity.com/id/evcentric
# 3              doctr                 http://steamcommunity.com/id/doctr
# 4          maplemage             http://steamcommunity.com/id/maplemage
#
#                                              reviews
# 0  [{'funny': '', 'posted': 'Posted November 5, 2...
# 1  [{'funny': '', 'posted': 'Posted June 24, 2014...
# 2  [{'funny': '', 'posted': 'Posted February 3.',...
# 3  [{'funny': '', 'posted': 'Posted October 14, 2...
# 4  [{'funny': '3 people found this review funny',...

# %%
reviews.drop(columns=['user_url'],inplace=True)

# %%
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25799 entries, 0 to 25798
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   user_id  25799 non-null  object
#  1   reviews  25799 non-null  object
# dtypes: object(2)
# memory usage: 403.2+ KB

# %%
reviews=reviews.explode('reviews')

# %%
reviews
# Out:
#                  user_id                                            reviews
# 0      76561197970982479  {'funny': '', 'posted': 'Posted November 5, 20...
# 0      76561197970982479  {'funny': '', 'posted': 'Posted July 15, 2011....
# 0      76561197970982479  {'funny': '', 'posted': 'Posted April 21, 2011...
# 1                js41637  {'funny': '', 'posted': 'Posted June 24, 2014....
# 1                js41637  {'funny': '', 'posted': 'Posted September 8, 2...
# ...                  ...                                                ...
# 25797  76561198312638244  {'funny': '', 'posted': 'Posted July 10.', 'la...
# 25797  76561198312638244  {'funny': '', 'posted': 'Posted July 8.', 'las...
# 25798        LydiaMorley  {'funny': '1 person found this review funny', ...
# 25798        LydiaMorley  {'funny': '', 'posted': 'Posted July 20.', 'la...
# 25798        LydiaMorley  {'funny': '', 'posted': 'Posted July 2.', 'las...
#
# [59333 rows x 2 columns]

# %%
reviews.sort_values('user_id', inplace=True)

# %%
df=reviews['reviews'].apply(pd.Series)

# %%
df
# Out:
#       funny                     posted                      last_edited  \
# 8342            Posted March 20, 2014.
# 25239             Posted May 30, 2014.
# 25239         Posted January 24, 2014.
# 12954                  Posted March 2.
# 12954          Posted August 15, 2015.
# ...     ...                        ...                              ...
# 24058        Posted December 23, 2013.      Last edited March 10, 2015.
# 24058             Posted May 18, 2013.
# 24058        Posted December 23, 2013.  Last edited September 25, 2014.
# 24058         Posted February 1, 2015.
# 17417        Posted November 13, 2015.
#
#       item_id                                         helpful recommend  \
# 8342     1250  1 of 1 people (100%) found this review helpful      True
# 25239  113200    0 of 1 people (0%) found this review helpful      True
# 25239     440   2 of 3 people (67%) found this review helpful      True
# 12954     730                                  No ratings yet      True
# 12954  105600                                  No ratings yet      True
# ...       ...                                             ...       ...
# 24058    8980    0 of 4 people (0%) found this review helpful      True
# 24058     440    0 of 1 people (0%) found this review helpful      True
# 24058   72850   1 of 2 people (50%) found this review helpful      True
# 24058     730   2 of 5 people (40%) found this review helpful      True
# 17417  280790                                  No ratings yet      True
#
#                                                   review   0
# 8342                                 หนุกคับ แนะนำ 10/10 NaN
# 25239  One Of The Funnyest Games That Is Animated :) ... NaN
# 25239                      the best game i ever plllayed NaN
# 12954  it done brokeded on me, the game no longer wor... NaN
# 12954  It's an amazing game, and im glad that mac use... NaN
# ...                                                  ...  ..
# 24058  A Gem.It's level of stupidity is just overwhem... NaN
# 24058  THis FPS Shooter game really packs a punch.I'm... NaN
# 24058  It's been a long way since Elder Scrolls start... NaN
# 24058  After playing 500 hours on this fantastic FPS,... NaN
# 17417  Ok, ok, i am a VietNamese and excuse me for th... NaN
#
# [59333 rows x 8 columns]

# %%
df.columns
# Out:
# Index([      'funny',      'posted', 'last_edited',     'item_id',
#            'helpful',   'recommend',      'review',             0],
#       dtype='object')

# %%
df.drop(columns=[      'funny',       'last_edited',     
           'helpful',             0], inplace=True)

# %%
df
# Out:
#                           posted item_id recommend  \
# 8342      Posted March 20, 2014.    1250      True
# 25239       Posted May 30, 2014.  113200      True
# 25239   Posted January 24, 2014.     440      True
# 12954            Posted March 2.     730      True
# 12954    Posted August 15, 2015.  105600      True
# ...                          ...     ...       ...
# 24058  Posted December 23, 2013.    8980      True
# 24058       Posted May 18, 2013.     440      True
# 24058  Posted December 23, 2013.   72850      True
# 24058   Posted February 1, 2015.     730      True
# 17417  Posted November 13, 2015.  280790      True
#
#                                                   review
# 8342                                 หนุกคับ แนะนำ 10/10
# 25239  One Of The Funnyest Games That Is Animated :) ...
# 25239                      the best game i ever plllayed
# 12954  it done brokeded on me, the game no longer wor...
# 12954  It's an amazing game, and im glad that mac use...
# ...                                                  ...
# 24058  A Gem.It's level of stupidity is just overwhem...
# 24058  THis FPS Shooter game really packs a punch.I'm...
# 24058  It's been a long way since Elder Scrolls start...
# 24058  After playing 500 hours on this fantastic FPS,...
# 17417  Ok, ok, i am a VietNamese and excuse me for th...
#
# [59333 rows x 4 columns]

# %%
rnames=reviews.drop_duplicates('user_id').copy()

# %%
rnames
# Out:
#             user_id                                            reviews
# 8342        --000--  {'funny': '', 'posted': 'Posted March 20, 2014...
# 25239       --ace--  {'funny': '', 'posted': 'Posted May 30, 2014.'...
# 12954     --ionex--  {'funny': '', 'posted': 'Posted March 2.', 'la...
# 18659  -2SV-vuLB-Kg  {'funny': '', 'posted': 'Posted October 15, 20...
# 367        -Azsael-  {'funny': '', 'posted': 'Posted February 23.',...
# ...             ...                                                ...
# 8814    zwanzigdrei  {'funny': '', 'posted': 'Posted July 25, 2015....
# 24992        zy0705  {'funny': '', 'posted': 'Posted August 11, 201...
# 21426    zynxgameth  {'funny': '', 'posted': 'Posted May 1, 2013.',...
# 24058       zyr0n1c  {'funny': '', 'posted': 'Posted July 15, 2013....
# 17417   zzoptimuszz  {'funny': '', 'posted': 'Posted November 13, 2...
#
# [25485 rows x 2 columns]

# %%
rnames.reset_index(inplace=True)

# %%
rnames
# Out:
#        index       user_id                                            reviews
# 0       8342       --000--  {'funny': '', 'posted': 'Posted March 20, 2014...
# 1      25239       --ace--  {'funny': '', 'posted': 'Posted May 30, 2014.'...
# 2      12954     --ionex--  {'funny': '', 'posted': 'Posted March 2.', 'la...
# 3      18659  -2SV-vuLB-Kg  {'funny': '', 'posted': 'Posted October 15, 20...
# 4        367      -Azsael-  {'funny': '', 'posted': 'Posted February 23.',...
# ...      ...           ...                                                ...
# 25480   8814   zwanzigdrei  {'funny': '', 'posted': 'Posted July 25, 2015....
# 25481  24992        zy0705  {'funny': '', 'posted': 'Posted August 11, 201...
# 25482  21426    zynxgameth  {'funny': '', 'posted': 'Posted May 1, 2013.',...
# 25483  24058       zyr0n1c  {'funny': '', 'posted': 'Posted July 15, 2013....
# 25484  17417   zzoptimuszz  {'funny': '', 'posted': 'Posted November 13, 2...
#
# [25485 rows x 3 columns]

# %%
rnames = rnames.rename(columns={'index': 'trash', 'user_id': 'user_name'})

# %%
rnames.reset_index(inplace=True)

# %%
rnames.columns
# Out:
# Index(['index', 'trash', 'user_name', 'reviews'], dtype='object')

# %%
rnames.drop(columns=['trash', 'reviews'], inplace=True)

# %%
rnames = rnames.rename(columns={'index':'user_id'})

# %%
rnames
# Out:
#        user_id     user_name
# 0            0       --000--
# 1            1       --ace--
# 2            2     --ionex--
# 3            3  -2SV-vuLB-Kg
# 4            4      -Azsael-
# ...        ...           ...
# 25480    25480   zwanzigdrei
# 25481    25481        zy0705
# 25482    25482    zynxgameth
# 25483    25483       zyr0n1c
# 25484    25484   zzoptimuszz
#
# [25485 rows x 2 columns]

# %%
rnames.to_parquet('../Datasets/rnames.parquet')

# %%
reviews = pd.concat([reviews, df], axis=1)

# %%
reviews
# Out:
#            user_id                                            reviews  \
# 8342       --000--  {'funny': '', 'posted': 'Posted March 20, 2014...
# 25239      --ace--  {'funny': '', 'posted': 'Posted May 30, 2014.'...
# 25239      --ace--  {'funny': '', 'posted': 'Posted January 24, 20...
# 12954    --ionex--  {'funny': '', 'posted': 'Posted March 2.', 'la...
# 12954    --ionex--  {'funny': '', 'posted': 'Posted August 15, 201...
# ...            ...                                                ...
# 24058      zyr0n1c  {'funny': '', 'posted': 'Posted December 23, 2...
# 24058      zyr0n1c  {'funny': '', 'posted': 'Posted May 18, 2013.'...
# 24058      zyr0n1c  {'funny': '', 'posted': 'Posted December 23, 2...
# 24058      zyr0n1c  {'funny': '', 'posted': 'Posted February 1, 20...
# 17417  zzoptimuszz  {'funny': '', 'posted': 'Posted November 13, 2...
#
#                           posted item_id recommend  \
# 8342      Posted March 20, 2014.    1250      True
# 25239       Posted May 30, 2014.  113200      True
# 25239   Posted January 24, 2014.     440      True
# 12954            Posted March 2.     730      True
# 12954    Posted August 15, 2015.  105600      True
# ...                          ...     ...       ...
# 24058  Posted December 23, 2013.    8980      True
# 24058       Posted May 18, 2013.     440      True
# 24058  Posted December 23, 2013.   72850      True
# 24058   Posted February 1, 2015.     730      True
# 17417  Posted November 13, 2015.  280790      True
#
#                                                   review
# 8342                                 หนุกคับ แนะนำ 10/10
# 25239  One Of The Funnyest Games That Is Animated :) ...
# 25239                      the best game i ever plllayed
# 12954  it done brokeded on me, the game no longer wor...
# 12954  It's an amazing game, and im glad that mac use...
# ...                                                  ...
# 24058  A Gem.It's level of stupidity is just overwhem...
# 24058  THis FPS Shooter game really packs a punch.I'm...
# 24058  It's been a long way since Elder Scrolls start...
# 24058  After playing 500 hours on this fantastic FPS,...
# 17417  Ok, ok, i am a VietNamese and excuse me for th...
#
# [59333 rows x 6 columns]

# %%
reviews = reviews.rename(columns={'user_id':'user_name'})

# %%
reviews = pd.merge(reviews,rnames,on='user_name')

# %%
reviews
# Out:
#          user_name                                            reviews  \
# 0          --000--  {'funny': '', 'posted': 'Posted March 20, 2014...
# 1          --ace--  {'funny': '', 'posted': 'Posted May 30, 2014.'...
# 2          --ace--  {'funny': '', 'posted': 'Posted January 24, 20...
# 3        --ionex--  {'funny': '', 'posted': 'Posted March 2.', 'la...
# 4        --ionex--  {'funny': '', 'posted': 'Posted August 15, 201...
# ...            ...                                                ...
# 59328      zyr0n1c  {'funny': '', 'posted': 'Posted December 23, 2...
# 59329      zyr0n1c  {'funny': '', 'posted': 'Posted May 18, 2013.'...
# 59330      zyr0n1c  {'funny': '', 'posted': 'Posted December 23, 2...
# 59331      zyr0n1c  {'funny': '', 'posted': 'Posted February 1, 20...
# 59332  zzoptimuszz  {'funny': '', 'posted': 'Posted November 13, 2...
#
#                           posted item_id recommend  \
# 0         Posted March 20, 2014.    1250      True
# 1           Posted May 30, 2014.  113200      True
# 2       Posted January 24, 2014.     440      True
# 3                Posted March 2.     730      True
# 4        Posted August 15, 2015.  105600      True
# ...                          ...     ...       ...
# 59328  Posted December 23, 2013.    8980      True
# 59329       Posted May 18, 2013.     440      True
# 59330  Posted December 23, 2013.   72850      True
# 59331   Posted February 1, 2015.     730      True
# 59332  Posted November 13, 2015.  280790      True
#
#                                                   review  user_id
# 0                                    หนุกคับ แนะนำ 10/10        0
# 1      One Of The Funnyest Games That Is Animated :) ...        1
# 2                          the best game i ever plllayed        1
# 3      it done brokeded on me, the game no longer wor...        2
# 4      It's an amazing game, and im glad that mac use...        2
# ...                                                  ...      ...
# 59328  A Gem.It's level of stupidity is just overwhem...    25483
# 59329  THis FPS Shooter game really packs a punch.I'm...    25483
# 59330  It's been a long way since Elder Scrolls start...    25483
# 59331  After playing 500 hours on this fantastic FPS,...    25483
# 59332  Ok, ok, i am a VietNamese and excuse me for th...    25484
#
# [59333 rows x 7 columns]

# %%
reviews.drop(columns=['user_name','reviews'], inplace=True)

# %%
reviews
# Out:
#                           posted item_id recommend  \
# 0         Posted March 20, 2014.    1250      True
# 1           Posted May 30, 2014.  113200      True
# 2       Posted January 24, 2014.     440      True
# 3                Posted March 2.     730      True
# 4        Posted August 15, 2015.  105600      True
# ...                          ...     ...       ...
# 59328  Posted December 23, 2013.    8980      True
# 59329       Posted May 18, 2013.     440      True
# 59330  Posted December 23, 2013.   72850      True
# 59331   Posted February 1, 2015.     730      True
# 59332  Posted November 13, 2015.  280790      True
#
#                                                   review  user_id
# 0                                    หนุกคับ แนะนำ 10/10        0
# 1      One Of The Funnyest Games That Is Animated :) ...        1
# 2                          the best game i ever plllayed        1
# 3      it done brokeded on me, the game no longer wor...        2
# 4      It's an amazing game, and im glad that mac use...        2
# ...                                                  ...      ...
# 59328  A Gem.It's level of stupidity is just overwhem...    25483
# 59329  THis FPS Shooter game really packs a punch.I'm...    25483
# 59330  It's been a long way since Elder Scrolls start...    25483
# 59331  After playing 500 hours on this fantastic FPS,...    25483
# 59332  Ok, ok, i am a VietNamese and excuse me for th...    25484
#
# [59333 rows x 5 columns]

# %%
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59333 entries, 0 to 59332
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   posted     59305 non-null  object
#  1   item_id    59305 non-null  object
#  2   recommend  59305 non-null  object
#  3   review     59305 non-null  object
#  4   user_id    59333 non-null  int64
# dtypes: int64(1), object(4)
# memory usage: 2.3+ MB

# %%
reviews['posted'] = reviews['posted'].str.strip('.')

# %%
reviews['posted'] = reviews['posted'].str.extract(r'(\d{4})')

# %%
moda=reviews['posted'].mode()[0]

# %%
reviews['posted'].fillna(moda, inplace=True)

# %%
reviews['posted'] = reviews['posted'].astype(int)

# %%
reviews
# Out:
#        posted item_id recommend  \
# 0        2014    1250      True
# 1        2014  113200      True
# 2        2014     440      True
# 3        2014     730      True
# 4        2015  105600      True
# ...       ...     ...       ...
# 59328    2013    8980      True
# 59329    2013     440      True
# 59330    2013   72850      True
# 59331    2015     730      True
# 59332    2015  280790      True
#
#                                                   review  user_id
# 0                                    หนุกคับ แนะนำ 10/10        0
# 1      One Of The Funnyest Games That Is Animated :) ...        1
# 2                          the best game i ever plllayed        1
# 3      it done brokeded on me, the game no longer wor...        2
# 4      It's an amazing game, and im glad that mac use...        2
# ...                                                  ...      ...
# 59328  A Gem.It's level of stupidity is just overwhem...    25483
# 59329  THis FPS Shooter game really packs a punch.I'm...    25483
# 59330  It's been a long way since Elder Scrolls start...    25483
# 59331  After playing 500 hours on this fantastic FPS,...    25483
# 59332  Ok, ok, i am a VietNamese and excuse me for th...    25484
#
# [59333 rows x 5 columns]

# %%
# Función para realizar el análisis de sentimiento
def analyze_sentiment(review):
    try:
        # Crear un objeto SentimentIntensityAnalyzer
        analyzer = SentimentIntensityAnalyzer()

        # Obtener la puntuación de sentimiento
        sentiment_score = analyzer.polarity_scores(str(review))['compound']

        # Mapear el resultado a la escala especificada
        if sentiment_score >= 0.05:
            return 2  # Positivo
        elif sentiment_score <= -0.05:
            return 0  # Negativo
        else:
            return 1  # Neutral
    except:
        return 1  # En caso de error o reseña ausente, asignar neutral

# %%
# Aplicar la función a la columna 'review' y crear la nueva columna 'sentiment_analysis'
reviews['sentiment_analysis'] = reviews['review'].apply(analyze_sentiment)

# Eliminar la columna original 'review' si es necesario
reviews.drop('review', axis=1, inplace=True)

reviews.to_parquet("../Datasets/reviews.parquet", index=False)

# %%
reviews
# Out:
#        posted item_id recommend  user_id  sentiment_analysis
# 0        2014    1250      True        0                   1
# 1        2014  113200      True        1                   2
# 2        2014     440      True        1                   2
# 3        2014     730      True        2                   2
# 4        2015  105600      True        2                   2
# ...       ...     ...       ...      ...                 ...
# 59328    2013    8980      True    25483                   2
# 59329    2013     440      True    25483                   1
# 59330    2013   72850      True    25483                   2
# 59331    2015     730      True    25483                   2
# 59332    2015  280790      True    25484                   2
#
# [59333 rows x 5 columns]

# %%
reviews['sentiment_analysis'].value_counts()
# Out:
# sentiment_analysis
# 2    40010
# 1    11010
# 0     8313
# Name: count, dtype: int64
