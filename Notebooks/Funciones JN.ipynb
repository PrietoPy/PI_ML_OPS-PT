# %%
import pandas as pd

# %%
games = pd.read_parquet('../pi_mlops_pt/Datasets/gamesv5.parquet')
reviews = pd.read_parquet('../pi_mlops_pt/Datasets/reviews.parquet')
items = pd.read_parquet('../pi_mlops_pt/Datasets/itemsv2.parquet')

# %%
generos = list(games.drop(columns=['item_id','release_date']).columns)

# %%
ids =pd.read_csv('../pi_mlops_pt/Datasets/idsnv2.csv')

# %%
iid=list(set(items['item_id']))

# %%
lanio=list(set(reviews['posted'].to_list()))

# %% [markdown]
# def PlayTimeGenre( genero : str ): Debe devolver año con mas horas jugadas para dicho género.
#
# Ejemplo de retorno:
#
# {"Año de lanzamiento con más horas jugadas para Género X" : 2013}

# %%
genero='2D'
lgames = games.loc[games['Action'] == 1, ['release_date', 'item_id']]

# %%
lgames.head()
# Out:
#     release_date      id
# 1           2018  761140
# 30          2017  767400
# 33          2018  772540
# 57          2018  770380
# 92          2018  768060

# %%
lhoras = items.groupby('item_id')['playtime_forever'].sum().reset_index()

# %%
lhoras.head()
# Out:
#    item_id  playtime_forever
# 0       10        17386015.0
# 1       20          961702.0
# 2       30          758991.0
# 3       40          154486.0
# 4       50          734562.0

# %%
dfplay = pd.merge(lgames, lhoras, on='item_id', how='inner')

# %%
dfplay.head()
# Out:
#    release_date    id  playtime_forever
# 0          2007  6510           43655.0
# 1          2007  2540            6363.0
# 2          2007  8000          102745.0
# 3          2007  9030            8996.0
# 4          2007  2310           93387.0

# %%
df_horas = dfplay.groupby('release_date')['playtime_forever'].sum().reset_index()

# %%
df_horas_ordenado = df_horas.sort_values(by='playtime_forever', ascending=False)
resultado=df_horas_ordenado.head(1)

# %%
resultado
# Out:
#    release_date  playtime_forever
# 5          2012      1.149773e+09

# %%
prin = "Año de lanzamiento con más horas jugadas para Género " + genero
anio = int(resultado['release_date'])

# %%
anio
# Out:
# 2012

# %%
dic={prin : anio}

# %%
dic
# Out:
# {'Año de lanzamiento con más horas jugadas para Género 2D': 2012}

# %%
def PlayTimeGenre(genero):
  genero=genero.upper()
  if genero in generos:
    lgames = games.loc[games[genero] == 1, ['release_date', 'item_id']]
    lhoras = items.groupby('item_id')['playtime_forever'].sum().reset_index()
    dfplay = pd.merge(lgames, lhoras, on='item_id', how='inner')
    df_horas = dfplay.groupby('release_date')['playtime_forever'].sum().reset_index()
    df_horas_ordenado = df_horas.sort_values(by='playtime_forever', ascending=False)
    resultado=df_horas_ordenado.head(1)
    prin = "Año de lanzamiento con más horas jugadas para Género " + genero
    anio = int(resultado['release_date'].iloc[0])
    return {prin : anio}
  else:
    return {"El Genero indicado no se encuentra en la base de datos":genero}

# %%
PlayTimeGenre("2d")
# Out:
# {'Año de lanzamiento con más horas jugadas para Género 2D': 2011}

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157825 entries, 0 to 157824
# Data columns (total 63 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   item_id                157825 non-null  int64
#  1   release_date           157825 non-null  int64
#  2   2D                     157825 non-null  uint8
#  3   ACTION                 157825 non-null  uint8
#  4   ADVENTURE              157825 non-null  uint8
#  5   ANIME                  157825 non-null  uint8
#  6   ARCADE                 157825 non-null  uint8
#  7   ATMOSPHERIC            157825 non-null  uint8
#  8   CASUAL                 157825 non-null  uint8
#  9   CLASSIC                157825 non-null  uint8
#  10  CO-OP                  157825 non-null  uint8
#  11  COMEDY                 157825 non-null  uint8
#  12  CUTE                   157825 non-null  uint8
#  13  DESIGN & ILLUSTRATION  157825 non-null  uint8
#  14  DIFFICULT              157825 non-null  uint8
#  15  EARLY ACCESS           157825 non-null  uint8
#  16  EXPLORATION            157825 non-null  uint8
#  17  FPS                    157825 non-null  uint8
#  18  FAMILY FRIENDLY        157825 non-null  uint8
#  19  FANTASY                157825 non-null  uint8
#  20  FEMALE PROTAGONIST     157825 non-null  uint8
#  21  FIRST-PERSON           157825 non-null  uint8
#  22  FREE TO PLAY           157825 non-null  uint8
#  23  FUNNY                  157825 non-null  uint8
#  24  GORE                   157825 non-null  uint8
#  25  GREAT SOUNDTRACK       157825 non-null  uint8
#  26  HIDDEN OBJECT          157825 non-null  uint8
#  27  HORROR                 157825 non-null  uint8
#  28  INDIE                  157825 non-null  uint8
#  29  LOCAL CO-OP            157825 non-null  uint8
#  30  LOCAL MULTIPLAYER      157825 non-null  uint8
#  31  MASSIVELY MULTIPLAYER  157825 non-null  uint8
#  32  MOVIE                  157825 non-null  uint8
#  33  MULTIPLAYER            157825 non-null  uint8
#  34  ONLINE CO-OP           157825 non-null  uint8
#  35  OPEN WORLD             157825 non-null  uint8
#  36  PIXEL GRAPHICS         157825 non-null  uint8
#  37  PLATFORMER             157825 non-null  uint8
#  38  POINT & CLICK          157825 non-null  uint8
#  39  PUZZLE                 157825 non-null  uint8
#  40  RPG                    157825 non-null  uint8
#  41  RPGMAKER               157825 non-null  uint8
#  42  RACING                 157825 non-null  uint8
#  43  RETRO                  157825 non-null  uint8
#  44  ROGUE-LIKE             157825 non-null  uint8
#  45  SANDBOX                157825 non-null  uint8
#  46  SCI-FI                 157825 non-null  uint8
#  47  SHOOT 'EM UP           157825 non-null  uint8
#  48  SHOOTER                157825 non-null  uint8
#  49  SIMULATION             157825 non-null  uint8
#  50  SINGLEPLAYER           157825 non-null  uint8
#  51  SPACE                  157825 non-null  uint8
#  52  SPORTS                 157825 non-null  uint8
#  53  STORY RICH             157825 non-null  uint8
#  54  STRATEGY               157825 non-null  uint8
#  55  SURVIVAL               157825 non-null  uint8
#  56  TACTICAL               157825 non-null  uint8
#  57  THIRD PERSON           157825 non-null  uint8
#  58  TURN-BASED             157825 non-null  uint8
#  59  UTILITIES              157825 non-null  uint8
#  60  VIOLENT                157825 non-null  uint8
#  61  VISUAL NOVEL           157825 non-null  uint8
#  62  ZOMBIES                157825 non-null  uint8
# dtypes: int64(2), uint8(61)
# memory usage: 11.6 MB

# %%
items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5153209 entries, 0 to 5153208
# Data columns (total 4 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   item_id           int64
#  1   item_name         object
#  2   playtime_forever  float64
#  3   user_id           object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 157.3+ MB

# %% [markdown]
# def UserForGenre( genero : str ): Debe devolver el usuario que acumula más horas jugadas para el género dado y una lista de la acumulación de horas jugadas por año.
#
#
# Ejemplo de retorno:
#
# {"Usuario con más horas jugadas para Género X" : us213ndjss09sdf, "Horas jugadas":[{Año: 2013, Horas: 203}, {Año: 2012, Horas: 100}, {Año: 2011, Horas: 23}]}

# %%
genero='RPG'
dfgames = games[['item_id','release_date',genero]]
dfgames = dfgames[games[genero]==1]
dfuserg = pd.merge(dfgames,items,on='item_id',how='inner')
dfuserg
# Out:
#          item_id  release_date  RPG                       item_name  \
# 0           1640          2006    1  Disciples II: Gallean's Return
# 1           1640          2006    1  Disciples II: Gallean's Return
# 2           1640          2006    1  Disciples II: Gallean's Return
# 3           1640          2006    1  Disciples II: Gallean's Return
# 4           1640          2006    1  Disciples II: Gallean's Return
# ...          ...           ...  ...                             ...
# 1337148    13230          2004    1          Unreal Tournament 2004
# 1337149    13230          2004    1          Unreal Tournament 2004
# 1337150    13230          2004    1          Unreal Tournament 2004
# 1337151    13230          2004    1          Unreal Tournament 2004
# 1337152    13230          2004    1          Unreal Tournament 2004
#
#          playtime_forever            user_id
# 0                     0.0           deathnz1
# 1                  1984.0  76561197970628046
# 2                     0.0        chidori_647
# 3                    17.0  76561198007539695
# 4                   386.0             thebtb
# ...                   ...                ...
# 1337148             430.0               Z427
# 1337149               4.0        2JZEEEEBABY
# 1337150              99.0  76561198094722660
# 1337151               0.0        geekmannerd
# 1337152               0.0  76561198273508956
#
# [1337153 rows x 6 columns]

# %%
uhoras = dfuserg.groupby('user_id')['playtime_forever'].sum().reset_index()
uhoras = uhoras.sort_values(by='playtime_forever', ascending=False)
uhoras = uhoras.head(1)
uhoras = uhoras['user_id'].iloc[0]
dfuserg = dfuserg[dfuserg['user_id']==uhoras]
uhoras
# Out:
# 'shinomegami'

# %%
dfuserg = dfuserg.groupby('release_date')['playtime_forever'].sum().reset_index()
dfuserg = dfuserg.sort_values(by='release_date', ascending=False)
dfuserg = dfuserg[dfuserg['playtime_forever']>0]
dfuserg
# Out:
#     release_date  playtime_forever
# 17          2016           15550.0
# 16          2015          127914.0
# 15          2014          147338.0
# 14          2013          126490.0
# 13          2012           27524.0
# 12          2011           21072.0
# 11          2010           41407.0
# 10          2009            1384.0
# 9           2008            1305.0
# 8           2007          136710.0
# 7           2006            2023.0
# 6           2005             185.0
# 5           2004            1801.0
# 4           2003          530943.0
# 1           2000            8392.0
# 0           1999             377.0

# %%
di = []
dfuserg = dfuserg.astype(int)
dfuserg.rename(columns={'release_date': 'Año', 'playtime_forever':'Horas'}, inplace=True)
for _,row in dfuserg.iterrows():
  di.append(row.to_dict())
di
# Out:
# [{'Año': 2016, 'Horas': 15550},
#  {'Año': 2015, 'Horas': 127914},
#  {'Año': 2014, 'Horas': 147338},
#  {'Año': 2013, 'Horas': 126490},
#  {'Año': 2012, 'Horas': 27524},
#  {'Año': 2011, 'Horas': 21072},
#  {'Año': 2010, 'Horas': 41407},
#  {'Año': 2009, 'Horas': 1384},
#  {'Año': 2008, 'Horas': 1305},
#  {'Año': 2007, 'Horas': 136710},
#  {'Año': 2006, 'Horas': 2023},
#  {'Año': 2005, 'Horas': 185},
#  {'Año': 2004, 'Horas': 1801},
#  {'Año': 2003, 'Horas': 530943},
#  {'Año': 2000, 'Horas': 8392},
#  {'Año': 1999, 'Horas': 377}]

# %%
prin="Usuario con más horas jugadas para Género " + genero

# %%
{prin:uhoras,"Horas Jugadas":di}
# Out:
# {'Usuario con más horas jugadas para Género RPG': 'shinomegami',
#  'Horas Jugadas': [{'Año': 2016, 'Horas': 15550},
#   {'Año': 2015, 'Horas': 127914},
#   {'Año': 2014, 'Horas': 147338},
#   {'Año': 2013, 'Horas': 126490},
#   {'Año': 2012, 'Horas': 27524},
#   {'Año': 2011, 'Horas': 21072},
#   {'Año': 2010, 'Horas': 41407},
#   {'Año': 2009, 'Horas': 1384},
#   {'Año': 2008, 'Horas': 1305},
#   {'Año': 2007, 'Horas': 136710},
#   {'Año': 2006, 'Horas': 2023},
#   {'Año': 2005, 'Horas': 185},
#   {'Año': 2004, 'Horas': 1801},
#   {'Año': 2003, 'Horas': 530943},
#   {'Año': 2000, 'Horas': 8392},
#   {'Año': 1999, 'Horas': 377}]}

# %%
def UserForGenre(genero):
  genero=genero.upper()
  if genero in generos:
    dfgames = games[['item_id','release_date',genero]]
    dfgames = dfgames[games[genero]==1]
    dfuserg = pd.merge(dfgames,items,on='item_id',how='inner')
    uhoras = dfuserg.groupby('user_id')['playtime_forever'].sum().reset_index()
    uhoras = uhoras.sort_values(by='playtime_forever', ascending=False)
    uhoras = uhoras.head(1)
    uhoras = uhoras['user_id'].iloc[0]
    dfuserg = dfuserg[dfuserg['user_id']==uhoras]
    dfuserg = dfuserg.groupby('release_date')['playtime_forever'].sum().reset_index()
    dfuserg = dfuserg.sort_values(by='release_date', ascending=False)
    dfuserg = dfuserg[dfuserg['playtime_forever']>0]
    dfuserg = dfuserg.astype(int)
    dfuserg.rename(columns={'release_date': 'Año', 'playtime_forever':'Horas'}, inplace=True)
    di = dfuserg.apply(lambda row: row.to_dict(), axis=1).tolist()
    prin="Usuario con más horas jugadas para Género " + genero
    return {prin:uhoras,"Horas Jugadas":di}
  else:
    return {"El Genero indicado no se encuentra en la base de datos ":genero}

# %%
UserForGenre('AcTiOn')
# Out:
# {'Usuario con más horas jugadas para Género ACTION': 'Sp3ctre',
#  'Horas Jugadas': [{'Año': 2017, 'Horas': 43327},
#   {'Año': 2016, 'Horas': 30195},
#   {'Año': 2015, 'Horas': 394314},
#   {'Año': 2014, 'Horas': 132864},
#   {'Año': 2013, 'Horas': 122158},
#   {'Año': 2012, 'Horas': 384238},
#   {'Año': 2011, 'Horas': 155459},
#   {'Año': 2010, 'Horas': 82766},
#   {'Año': 2009, 'Horas': 108771},
#   {'Año': 2008, 'Horas': 8533},
#   {'Año': 2007, 'Horas': 112794},
#   {'Año': 2006, 'Horas': 90253},
#   {'Año': 2005, 'Horas': 21339},
#   {'Año': 2004, 'Horas': 127411},
#   {'Año': 2003, 'Horas': 7744},
#   {'Año': 2002, 'Horas': 238},
#   {'Año': 2001, 'Horas': 250},
#   {'Año': 2000, 'Horas': 70644},
#   {'Año': 1999, 'Horas': 44},
#   {'Año': 1997, 'Horas': 242},
#   {'Año': 1995, 'Horas': 217}]}

# %% [markdown]
# def UsersRecommend( año : int ): Devuelve el top 3 de juegos MÁS recomendados por usuarios para el año dado.
#
# (reviews.recommend = True y comentarios positivos/neutrales)
#
# Ejemplo de retorno: [{"Puesto 1" : X}, {"Puesto 2" : Y},{"Puesto 3" : Z}]

# %%
anio=2012

# %%
if anio in lanio:
  print('yes')
else:
  print('no')
# Out:
# yes

# %%
reviews.columns
# Out:
# Index(['user_id', 'posted', 'item_id', 'recommend', 'sentiment_analysis'], dtype='object')

# %%
dfa = reviews[(reviews['posted'] == anio) & (reviews['recommend'] == True) & (reviews['sentiment_analysis'] >0)].copy()
dfa
# Out:
#                     user_id  posted  item_id  recommend  sentiment_analysis
# 13                    doctr    2012    20920       True                   2
# 14                    doctr    2012   204100       True                   2
# 16                    doctr    2012   207610       True                   2
# 17                    doctr    2012   108710       True                   2
# 24                   Wackky    2012      550       True                   2
# ...                     ...     ...      ...        ...                 ...
# 59270           SenpaiDemon    2012      730       True                   2
# 59272  Fuckfhaisjnsnsjakaka    2012      730       True                   2
# 59274          ChrisCoroner    2012   209120       True                   2
# 59296              Ghoustik    2012      730       True                   1
# 59303           LydiaMorley    2012      730       True                   2
#
# [2028 rows x 5 columns]

# %%
dfa = dfa.groupby('item_id')['sentiment_analysis'].sum().reset_index()
dfa = dfa.sort_values('sentiment_analysis', ascending=False)
dfa.head(3)
# Out:
#      item_id  sentiment_analysis
# 15       730                1041
# 9        440                 431
# 150    49520                  97

# %%
top_games = dfa.head(3)['item_id'].to_list()
top_games
# Out:
# [730, 440, 49520]

# %%
top_games[0]
# Out:
# 730

# %%
top_games[1]
# Out:
# 440

# %%
top_games[2]
# Out:
# 49520

# %%
items[items['item_id'] == top_games[0]].head(1)['item_name'].iloc[0]
# Out:
# 'Counter-Strike: Global Offensive'

# %%
ids[ids['item_id'] == top_games[1]].head(1)['item_name'].iloc[0]
# Out:
# 'Team Fortress 2'

# %%
items[items['item_id'] == top_games[2]].head(1)['item_name'].iloc[0]
# Out:
# 'Borderlands 2'

# %%
def UsersRecommend(anio):
  if anio in lanio:
    dfa = reviews[(reviews['posted'] == anio) & (reviews['recommend'] == True) & (reviews['sentiment_analysis'] >0)].copy()
    dfa = dfa.groupby('item_id')['sentiment_analysis'].sum().reset_index()
    dfa = dfa.sort_values('sentiment_analysis', ascending=False)
    top_games = dfa.head(3)['item_id'].to_list()
    for i,g in enumerate(top_games):
      if g in iid:
        top_games[i]=items[items['item_id'] == top_games[i]].head(1)['item_name'].iloc[0]
      else:
        top_games[i]=ids[ids['item_id'] == top_games[i]].head(1)['item_name'].iloc[0]
    return{'Puesto 1':top_games[0],'Puesto 2':top_games[1],'Puesto 3':top_games[2]}
  else:
    return {f'El año indicado no se encuentra en la base de datos: ':anio}

# %%
UsersRecommend(2012)
# Out:
# {'Puesto 1': 'Counter-Strike: Global Offensive',
#  'Puesto 2': 'Team Fortress 2',
#  'Puesto 3': 'Borderlands 2'}

# %% [markdown]
# def UsersNotRecommend( año : int ): Devuelve el top 3 de juegos MENOS recomendados por usuarios para el año dado.
#
#  (reviews.recommend = False y comentarios negativos)
#
#
# Ejemplo de retorno: [{"Puesto 1" : X}, {"Puesto 2" : Y},{"Puesto 3" : Z}]

# %%
anio=2012

# %%
 dfa = reviews[(reviews['posted'] == anio) & (reviews['recommend'] == False) & (reviews['sentiment_analysis'] ==0)].copy()

# %%
dfa
# Out:
#                      user_id  posted  item_id  recommend  sentiment_analysis
# 358        76561198115868847    2012   219640      False                   0
# 385        76561198065593074    2012      730      False                   0
# 486                   jjas01    2012   212630      False                   0
# 688        76561198085956238    2012   224540      False                   0
# 1153               Brayneeah    2012   211420      False                   0
# 5320       76561198086462653    2012      730      False                   0
# 5701     smokeaconeorfuckoff    2012   219640      False                   0
# 8521       76561198081009511    2012   219640      False                   0
# 8841            commandochou    2012   211400      False                   0
# 9267                 BlueYuY    2012      730      False                   0
# 9695           vitorgamer115    2012   200210      False                   0
# 10341               crixis48    2012      730      False                   0
# 10430            CheeZeIzLuv    2012      730      False                   0
# 10500           itsdandytime    2012      730      False                   0
# 10900      76561198081440969    2012   225640      False                   0
# 11201            DefNotPeter    2012    55110      False                   0
# 11592             elkpodeush    2012      730      False                   0
# 11775      76561198066295384    2012      730      False                   0
# 12647      76561198091081910    2012   215470      False                   0
# 12893      76561198058405866    2012   218230      False                   0
# 13085      76561197999260941    2012   212630      False                   0
# 13582             INSERTCASH    2012   208570      False                   0
# 15496      76561198059020961    2012   208480      False                   0
# 15591      76561198034277356    2012      440      False                   0
# 16674          Artful-dodgeR    2012   211160      False                   0
# 16925            PlushTurtle    2012    42920      False                   0
# 17455      76561198053799839    2012      730      False                   0
# 17602          adamsucksdick    2012      730      False                   0
# 20649               Foxxy346    2012      730      False                   0
# 21162        purplecubefruit    2012   105000      False                   0
# 22048      76561198063988983    2012   209870      False                   0
# 24204    cumtasteslikejelley    2012   224540      False                   0
# 24367                addicTT    2012    42680      False                   0
# 27060                sasssay    2012      730      False                   0
# 29887      76561198081498297    2012      730      False                   0
# 30220           fpstheroamer    2012   200210      False                   0
# 30477         evilrussell117    2012   218230      False                   0
# 30525                bhajina    2012    24240      False                   0
# 30586                luakbar    2012   218230      False                   0
# 30812      76561198010436866    2012   200510      False                   0
# 31452              ImJustPro    2012      730      False                   0
# 32884      76561198053674558    2012   204300      False                   0
# 35262      theguywithnobrain    2012   209870      False                   0
# 36407      76561198273284475    2012   224540      False                   0
# 36453      76561198093124034    2012      730      False                   0
# 36455      76561198093124034    2012   204300      False                   0
# 36472              niffirg11    2012   220240      False                   0
# 38239            qwazyoxyphi    2012   203140      False                   0
# 38444             ravichop89    2012      730      False                   0
# 39542   45236243663663643636    2012      730      False                   0
# 39788                gigipig    2012      730      False                   0
# 42179             tinyacb706    2012      730      False                   0
# 42907  BayonetSpaghettiKnife    2012      730      False                   0
# 47098          LordMinion777    2012      730      False                   0
# 48526              jaydanred    2012      730      False                   0
# 52049      76561198069628927    2012      730      False                   0
# 53462                 mazokn    2012      730      False                   0

# %%
dfa['sentiment_analysis']=1
dfa
# Out:
#                      user_id  posted  item_id  recommend  sentiment_analysis
# 358        76561198115868847    2012   219640      False                   1
# 385        76561198065593074    2012      730      False                   1
# 486                   jjas01    2012   212630      False                   1
# 688        76561198085956238    2012   224540      False                   1
# 1153               Brayneeah    2012   211420      False                   1
# 5320       76561198086462653    2012      730      False                   1
# 5701     smokeaconeorfuckoff    2012   219640      False                   1
# 8521       76561198081009511    2012   219640      False                   1
# 8841            commandochou    2012   211400      False                   1
# 9267                 BlueYuY    2012      730      False                   1
# 9695           vitorgamer115    2012   200210      False                   1
# 10341               crixis48    2012      730      False                   1
# 10430            CheeZeIzLuv    2012      730      False                   1
# 10500           itsdandytime    2012      730      False                   1
# 10900      76561198081440969    2012   225640      False                   1
# 11201            DefNotPeter    2012    55110      False                   1
# 11592             elkpodeush    2012      730      False                   1
# 11775      76561198066295384    2012      730      False                   1
# 12647      76561198091081910    2012   215470      False                   1
# 12893      76561198058405866    2012   218230      False                   1
# 13085      76561197999260941    2012   212630      False                   1
# 13582             INSERTCASH    2012   208570      False                   1
# 15496      76561198059020961    2012   208480      False                   1
# 15591      76561198034277356    2012      440      False                   1
# 16674          Artful-dodgeR    2012   211160      False                   1
# 16925            PlushTurtle    2012    42920      False                   1
# 17455      76561198053799839    2012      730      False                   1
# 17602          adamsucksdick    2012      730      False                   1
# 20649               Foxxy346    2012      730      False                   1
# 21162        purplecubefruit    2012   105000      False                   1
# 22048      76561198063988983    2012   209870      False                   1
# 24204    cumtasteslikejelley    2012   224540      False                   1
# 24367                addicTT    2012    42680      False                   1
# 27060                sasssay    2012      730      False                   1
# 29887      76561198081498297    2012      730      False                   1
# 30220           fpstheroamer    2012   200210      False                   1
# 30477         evilrussell117    2012   218230      False                   1
# 30525                bhajina    2012    24240      False                   1
# 30586                luakbar    2012   218230      False                   1
# 30812      76561198010436866    2012   200510      False                   1
# 31452              ImJustPro    2012      730      False                   1
# 32884      76561198053674558    2012   204300      False                   1
# 35262      theguywithnobrain    2012   209870      False                   1
# 36407      76561198273284475    2012   224540      False                   1
# 36453      76561198093124034    2012      730      False                   1
# 36455      76561198093124034    2012   204300      False                   1
# 36472              niffirg11    2012   220240      False                   1
# 38239            qwazyoxyphi    2012   203140      False                   1
# 38444             ravichop89    2012      730      False                   1
# 39542   45236243663663643636    2012      730      False                   1
# 39788                gigipig    2012      730      False                   1
# 42179             tinyacb706    2012      730      False                   1
# 42907  BayonetSpaghettiKnife    2012      730      False                   1
# 47098          LordMinion777    2012      730      False                   1
# 48526              jaydanred    2012      730      False                   1
# 52049      76561198069628927    2012      730      False                   1
# 53462                 mazokn    2012      730      False                   1

# %%
dfa = dfa.groupby('item_id')['sentiment_analysis'].sum().reset_index()
dfa = dfa.sort_values('sentiment_analysis', ascending=False)
dfa.head(3)
# Out:
#     item_id  sentiment_analysis
# 1       730                  24
# 22   224540                   3
# 20   219640                   3

# %%
def UsersNotRecommend(anio):
  if anio in lanio:
    dfa = reviews[(reviews['posted'] == anio) & (reviews['recommend'] == False) & (reviews['sentiment_analysis'] ==0)].copy()
    dfa['sentiment_analysis']=1
    dfa = dfa.groupby('item_id')['sentiment_analysis'].sum().reset_index()
    dfa = dfa.sort_values('sentiment_analysis', ascending=False)
    top_games = dfa.head(3)['item_id'].to_list()
    for i,g in enumerate(top_games):
      if g in iid:
        top_games[i]=items[items['item_id'] == top_games[i]].head(1)['item_name'].iloc[0]
      else:
        top_games[i]=ids[ids['item_id'] == top_games[i]].head(1)['item_name'].iloc[0]
    if len(top_games)<2:
      return{'Puesto 1':top_games[0],'Puesto 2':'','Puesto 3':''}
    elif len(top_games)<3:
      return{'Puesto 1':top_games[0],'Puesto 2':top_games[1],'Puesto 3':''}
    else:
      return{'Puesto 1':top_games[0],'Puesto 2':top_games[1],'Puesto 3':top_games[2]}
  else:
    return {f'El año indicado no se encuentra en la base de datos: ':anio}

# %%
UsersNotRecommend(2012)
# Out:
# {'Puesto 1': 'Counter-Strike: Global Offensive',
#  'Puesto 2': 'Ace of Spades',
#  'Puesto 3': 'Chivalry: Medieval Warfare'}

# %% [markdown]
# def sentiment_analysis( año : int ): Según el año de lanzamiento, se devuelve una lista con la cantidad de registros de reseñas de usuarios que se encuentren categorizados con un análisis de sentimiento.
#
# Ejemplo de retorno: {Negative = 182, Neutral = 120, Positive = 278}

# %%
anio=2014

# %%
games[['item_id','release_date']].drop_duplicates()
# Out:
#         item_id  release_date
# 0        761140          2018
# 5        643980          2018
# 24       670290          2017
# 30       767400          2017
# 33       772540          2018
# ...         ...           ...
# 157804   745400          2018
# 157809   773640          2018
# 157813   733530          2018
# 157816   610660          2018
# 157819   658870          2017
#
# [29803 rows x 2 columns]

# %%
dfs = pd.merge(reviews[['item_id','sentiment_analysis']],games[['item_id','release_date']].drop_duplicates(),on='item_id',how='inner')
dfs
# Out:
#        item_id  sentiment_analysis  release_date
# 0         1250                   2          2009
# 1         1250                   2          2009
# 2         1250                   0          2009
# 3         1250                   2          2009
# 4         1250                   2          2009
# ...        ...                 ...           ...
# 50572   307130                   2          2014
# 50573   209120                   2          2012
# 50574   220090                   1          2013
# 50575   262850                   1          2014
# 50576   431510                   2          2016
#
# [50577 rows x 3 columns]

# %%
dfs[dfs['release_date']==anio]
# Out:
#        item_id  sentiment_analysis  release_date
# 648     237930                   2          2014
# 649     237930                   0          2014
# 650     237930                   2          2014
# 651     237930                   2          2014
# 652     237930                   2          2014
# ...        ...                 ...           ...
# 50552   319970                   2          2014
# 50567   294230                   1          2014
# 50570   305920                   0          2014
# 50572   307130                   2          2014
# 50575   262850                   1          2014
#
# [6448 rows x 3 columns]

# %%
dfs=dfs[dfs['release_date']==anio]

# %%
dfs=dfs.groupby('sentiment_analysis').size().reset_index(name='count')
dfs=dfs.sort_values('sentiment_analysis', ascending=True)
dfs
# Out:
#    sentiment_analysis  count
# 0                   0   1040
# 1                   1   1067
# 2                   2   4341

# %%
dfs=dfs['count'].to_list()
dfs
# Out:
# [1040, 1067, 4341]

# %%
{'Negative':dfs[0],'Neutral':dfs[1],'Positive':dfs[2]}
# Out:
# {'Negative': 1040, 'Neutral': 1067, 'Positive': 4341}

# %%
def sentiment_analysis(anio):
  dfs = pd.merge(reviews[['item_id','sentiment_analysis']],games[['item_id','release_date']].drop_duplicates(),on='item_id',how='inner')
  dfs = dfs[dfs['release_date']==anio]
  dfs = dfs.groupby('sentiment_analysis').size().reset_index(name='count')
  dfs = dfs.sort_values('sentiment_analysis', ascending=True)
  dfs = dfs['count'].to_list()
  return{'Negative':dfs[0],'Neutral':dfs[1],'Positive':dfs[2]}

# %%
sentiment_analysis(2014)
# Out:
# {'Negative': 1040, 'Neutral': 1067, 'Positive': 4341}
