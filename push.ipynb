# %%
# Como estamos trabajando en colab y tengo los archivos en el drive importamos la libreria y montamos
from google.colab import drive #para utilizar google drive como fuente de archivos
drive.mount('/content/drive') #montamos la carpeta del drive
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/PI_ML_OPS-PT
# Out:
# /content/drive/MyDrive/PI_ML_OPS-PT

# %%
# !git rm --cached push.ipynb
# Out:
# fatal: pathspec 'push.ipynb' did not match any files

# %%
# !git add .

# %%
# !git config --global user.email "angelprieto92@gmail.com"

# %%
# !git config --global user.name "PrietoPy"

# %%
# !git commit -m "ETL casi OK, nb push en local"
# Out:
# [main 2064d4c] ETL casi OK, nb push en local
#  2 files changed, 2 insertions(+), 1 deletion(-)
#  create mode 100644 .gitignore.txt
#  rewrite push.ipynb (67%)

# %%
# !git push https://PrietoPy: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@github.com/PrietoPy/PI_ML_OPS-PT.git
# Out:
# Everything up-to-date
