# %%
# Como estamos trabajando en colab y tengo los archivos en el drive importamos la libreria y montamos
from google.colab import drive #para utilizar google drive como fuente de archivos
drive.mount('/content/drive') #montamos la carpeta del drive
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/PI_ML_OPS-PT
# Out:
# /content/drive/MyDrive/PI_ML_OPS-PT

# %%
# !git add .

# %%
#!git config --global user.email "angelprieto92@gmail.com"

# %%
#!git config --global user.name "PrietoPy"

# %%
# !git commit -m "ETL GAMES OK, Reviews falta npl, items falta TL"
# Out:
# [main cbd132f] ETL GAMES OK, Reviews falta npl, items falta TL
#  9 files changed, 300755 insertions(+), 166 deletions(-)
#  create mode 100644 Copia de Untitled1.ipynb
#  create mode 100644 Datasets/gamesv1.csv
#  create mode 100644 Datasets/gamesv2.csv
#  create mode 100644 Datasets/gamesv3.csv
#  create mode 100644 Datasets/items.parquet
#  create mode 100644 Datasets/itemso.parquet
#  create mode 100644 Datasets/reviews.json

# %%
# !git push https://PrietoPy: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@github.com/PrietoPy/PI_ML_OPS-PT.git
# Out:
# Enumerating objects: 16, done.
# Counting objects: 100% (16/16), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (12/12), done.
# Writing objects: 100% (12/12), 57.91 MiB | 5.94 MiB/s, done.
# Total 12 (delta 2), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/PrietoPy/PI_ML_OPS-PT.git
#    32c1ddc..cbd132f  main -> main
